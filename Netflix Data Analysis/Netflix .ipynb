# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df=pd.read_csv('/content/drive/MyDrive/dataset/mymoviedb.csv',lineterminator='\n')
df
# Out:
#      Release_Date                                 Title  \
# 0      2021-12-15               Spider-Man: No Way Home
# 1      2022-03-01                            The Batman
# 2      2022-02-25                               No Exit
# 3      2021-11-24                               Encanto
# 4      2021-12-22                        The King's Man
# ...           ...                                   ...
# 9822   1973-10-15                              Badlands
# 9823   2020-10-01                      Violent Delights
# 9824   2016-05-06                          The Offering
# 9825   2021-03-31  The United States vs. Billie Holiday
# 9826   1984-09-23                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
df.isnull().sum()
# Out:
# Release_Date         0
# Title                0
# Overview             0
# Popularity           0
# Vote_Count           0
# Vote_Average         0
# Original_Language    0
# Genre                0
# Poster_Url           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   object
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.1+ KB

# %%
df.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9827.000000   9827.000000   9827.000000
# mean     40.326088   1392.805536      6.439534
# std     108.873998   2611.206907      1.129759
# min      13.354000      0.000000      0.000000
# 25%      16.128500    146.000000      5.900000
# 50%      21.199000    444.000000      6.500000
# 75%      35.191500   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9822    False
# 9823    False
# 9824    False
# 9825    False
# 9826    False
# Length: 9827, dtype: bool

# %%
#df['Release_Date']=[i.split("-")[0] for i in df['Release_Date']]
df.rename(columns={'Release_Date':'Year'},inplace=True)
df['Year']=pd.to_datetime(df['Year'])
df['Year']=df['Year'].dt.year
df
# Out:
#       Year                                 Title  \
# 0     2021               Spider-Man: No Way Home
# 1     2022                            The Batman
# 2     2022                               No Exit
# 3     2021                               Encanto
# 4     2021                        The King's Man
# ...    ...                                   ...
# 9822  1973                              Badlands
# 9823  2020                      Violent Delights
# 9824  2016                          The Offering
# 9825  2021  The United States vs. Billie Holiday
# 9826  1984                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# 3     The tale of an extraordinary family, the Madri...    2402.201
# ...

# %%
#df.drop(columns=['Original_Language'],inplace=True)
df
# Out:
#       Year                                 Title  \
# 0     2021               Spider-Man: No Way Home
# 1     2022                            The Batman
# 2     2022                               No Exit
# 3     2021                               Encanto
# 4     2021                        The King's Man
# ...    ...                                   ...
# 9822  1973                              Badlands
# 9823  2020                      Violent Delights
# 9824  2016                          The Offering
# 9825  2021  The United States vs. Billie Holiday
# 9826  1984                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# 3     The tale of an extraordinary family, the Madri...    2402.201
# ...

# %%
def categorize(df,col,labels):
  value=[df[col].describe()['min'],
        df[col].describe()['25%'],
        df[col].describe()['50%'],
        df[col].describe()['75%'],
        df[col].describe()['max']]

  df[col]=pd.cut(df[col],value,labels=labels,duplicates='drop')
  return df

# %%
labels=['Not Popular','Below Avarage','Avarage','Popular']
categorize(df,'Vote_Average',labels)
df
# Out:
#       Year                                 Title  \
# 0     2021               Spider-Man: No Way Home
# 1     2022                            The Batman
# 2     2022                               No Exit
# 3     2021                               Encanto
# 4     2021                        The King's Man
# ...    ...                                   ...
# 9822  1973                              Badlands
# 9823  2020                      Violent Delights
# 9824  2016                          The Offering
# 9825  2021  The United States vs. Billie Holiday
# 9826  1984                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# 3     The tale of an extraordinary family, the Madri...    2402.201
# ...

# %%
df['Genre']=df['Genre'].str.split(", ")
df=df.explode('Genre').reset_index(drop=True)
df.head()
# Out:
#    Year                    Title  \
# 0  2021  Spider-Man: No Way Home
# 1  2021  Spider-Man: No Way Home
# 2  2021  Spider-Man: No Way Home
# 3  2022               The Batman
# 4  2022               The Batman
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 2  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 3  In his second year of fighting crime, Batman u...    3827.658        1151
# 4  In his second year of fighting crime, Batman u...    3827.658        1151
#
#   Vote_Average Original_Language            Genre  \
# 0      Popular                en           Action
# 1      Popular                en        Adventure
# 2      Popular                en  Science Fiction
# 3      Popular                en            Crime
# ...

# %%
df['Vote_Average'].value_counts()
# Out:
# Vote_Average
# Avarage          6613
# Popular          6520
# Below Avarage    6348
# Not Popular      6071
# Name: count, dtype: int64

# %%
df['Genre'].unique()
# Out:
# array(['Action', 'Adventure', 'Science Fiction', 'Crime', 'Mystery',
#        'Thriller', 'Animation', 'Comedy', 'Family', 'Fantasy', 'War',
#        'Horror', 'Drama', 'Music', 'Romance', 'Western', 'History',
#        'TV Movie', 'Documentary'], dtype=object)

# %%
sns.set_style('whitegrid')

# %%
sns.catplot(data=df,y='Genre',kind='count',order=df['Genre'].value_counts().index,color='#4287f5')
plt.title('Genre Distribution')
plt.show()

# %% [markdown]
# In This Graph we use the catplot to analyse that the Drama type of contenct has liked by the most number of audience. so if we work on drama project with a good story line then audience will love it.

# %%
sns.catplot(data=df,y='Vote_Average',kind='count',order=df['Vote_Average'].value_counts().index,color='#4287f5')
plt.title('vote Distribution')
plt.show()

# %% [markdown]
# Most Popular movie

# %%
df[df['Popularity']==df['Popularity'].max()]
# Out:
#    Year                    Title  \
# 0  2021  Spider-Man: No Way Home
# 1  2021  Spider-Man: No Way Home
# 2  2021  Spider-Man: No Way Home
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 2  Peter Parker is unmasked and no longer able to...    5083.954        8940
#
#   Vote_Average Original_Language            Genre  \
# 0      Popular                en           Action
# 1      Popular                en        Adventure
# 2      Popular                en  Science Fiction
#
#                                           Poster_Url
# 0  https://image.tmdb.org/t/p/original/1g0dhYtq4i...
# 1  https://image.tmdb.org/t/p/original/1g0dhYtq4i...
# 2  https://image.tmdb.org/t/p/original/1g0dhYtq4i...

# %% [markdown]
# In this analyse the Spider-Man: No Way Home	has the most number of popularity.

# %% [markdown]
# Least Popular Movie

# %%
df[df['Popularity']==df['Popularity'].min()]
# Out:
#        Year                                 Title  \
# 25787  2021  The United States vs. Billie Holiday
# 25788  2021  The United States vs. Billie Holiday
# 25789  2021  The United States vs. Billie Holiday
# 25790  1984                               Threads
# 25791  1984                               Threads
# 25792  1984                               Threads
#
#                                                 Overview  Popularity  \
# 25787  Billie Holiday spent much of her career being ...      13.354
# 25788  Billie Holiday spent much of her career being ...      13.354
# 25789  Billie Holiday spent much of her career being ...      13.354
# 25790  Documentary style account of a nuclear holocau...      13.354
# 25791  Documentary style account of a nuclear holocau...      13.354
# 25792  Documentary style account of a nuclear holocau...      13.354
#
#        Vote_Count Vote_Average Original_Language            Genre  \
# ...

# %% [markdown]
# in This analyse the The United States vs. Billie Holiday and Threads	has the least no of popularity.

# %% [markdown]
# Which year has the most movie released

# %%
#pv=df.pivot_table(index='Year',aggfunc='count')
#pv.sort_values(by='Title',ascending=False)
#sns.barplot(data=pv,x=pv.index,y='Title',color='#4287f5')
#plt.title('Release year Distribution')
#plt.show()
df['Year'].hist()
plt.title('Release year Distribution')
plt.show()

# %% [markdown]
# In this analyse we can get the most  content release year. In 2020 has the maximum number of release

# %% [markdown]
# Search Movie with Genre

# %%
n=input('Enter the Geren')
res=df[df['Genre']==n.capitalize()]
print(res)
# Out:
# Enter the Gerenwar
#        Year                      Title  \
# 14     2021             The King's Man
# 151    2022  Forgive Us Our Trespasses
# 331    2021             Zeros and Ones
# 371    2021                      Amina
# 390    2016              Hacksaw Ridge
# ...     ...                        ...
# 25396  1995                Underground
# 25443  2008          Winter in Wartime
# 25639  2017     The Ottoman Lieutenant
# 25700  1956        Alexander the Great
# 25790  1984                    Threads
#
#                                                 Overview  Popularity  \
# 14     As a collection of history's worst tyrants and...    1895.511
# 151    Targeted by Nazis as they hunt down and murder...     409.688
# 331    Called to Rome to stop an imminent terrorist b...     256.443
# 371    In 16th-century Zazzau, now Zaria, Nigeria, Am...     237.262
# 390    WWII American Army Medic Desmond T. Doss, who ...     230.758
# ...

# %% [markdown]
# ***Summary***
#
# This analysis of the provided Netflix dataset revealed several key trends regarding content popularity and distribution:
#
# Genre Dominance: The 'Drama' genre emerged as the most popular category, attracting the largest audience share within this dataset. This highlights the significant appeal of dramatic storytelling among the observed Netflix viewers.
#
# Top Performing Content: The film "Spider-Man: No Way Home" registered as the most popular individual title, indicating strong viewership performance likely driven by its blockbuster status and potential recent addition to the platform during the dataset's timeframe.
#
# Lower Popularity Titles: Conversely, the films "The United States vs. Billie Holiday" and the 1984 TV film "Threads" exhibited the lowest popularity scores. This may reflect factors such as niche appeal, limited regional availability on the platform, or the specific timeframe covered by the data.
#
# Release Year Peak: The year 2020 showed the highest concentration of content releases within the dataset. This peak likely reflects the unique circumstances of the COVID-19 pandemic, which saw numerous theatrical releases shift to streaming platforms and potentially altered production and acquisition schedules.

# %% [markdown]
# ***Conclusion***
#
# The analysis indicates that viewer preferences within this Netflix dataset align with broader industry trends, favouring the widely appealing 'Drama' genre. The standout popularity of a major recent blockbuster like "Spider-Man: No Way Home" underscores the impact of high-profile acquisitions on viewership metrics.
#
# The lower engagement with titles like "The United States vs. Billie Holiday" and "Threads" suggests that factors beyond genre, such as platform availability, marketing, and niche audience appeal, significantly influence popularity metrics within the Netflix ecosystem.
#
# Furthermore, the distinct peak in 2020 releases serves as a clear data point reflecting the significant disruption and strategic shifts within the film industry during the pandemic, particularly the accelerated move towards streaming distribution. These findings provide valuable insights into content performance and distribution patterns on Netflix, shaped by both inherent audience preferences and external industry dynamics. Further research could explore the correlation between release timing, genre, and long-term viewership, or delve deeper into the regional variations affecting content popularity.
